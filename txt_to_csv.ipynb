# %%
import pandas as pd

# %%
#delting empty lines and adding a dot at the end of each txt file (only execute once)

for i in range(1,64):
    index = '00' + str(i)
    index = index[-3:]
    with open('extracted_text/train/'+index+'.txt', 'r') as infile:
        data = infile.read()
    infile.close()
    with open('extracted_text/train/'+index+'.txt', 'w') as infile:
        infile.write(data[:-2])
    with open("extracted_text/train/"+index+'.txt', 'a') as infile:
        infile.writelines('\n.\n')
        infile.close()

# %%
#remove accents (requires original files to be utf-8 encoding)

for i in range(1,64):
    print('index is', i)
    index = '00' + str(i)
    index = index[-3:]
    with open('extracted_text/train/'+index+'.txt', 'r', encoding='utf-8') as file:
        data = file.read()
        print(data)
        accent = ['é', 'è', 'ê', 'à', 'ù', 'û', 'ç', 'ô', 'î', 'ï', 'â', 'É', 'È', 'Ê', 'À', 'Ù', 'Û', 'Ç', 'Ô', 'Î', 'Ï', 'Â']
        without_accent = ['e', 'e', 'e', 'a', 'u', 'u', 'c', 'o', 'i', 'i', 'a', 'E', 'E', 'E', 'A', 'U', 'U', 'C', 'O', 'I', 'I', 'A']
        i = 0
        while i < len(accent):
            data = data.replace(accent[i], without_accent[i])
            i += 1
        print(data)
    with open('extracted_text/train/'+index+'.txt', 'w', encoding='utf-8') as file:
        file.write(data)
# Out:
# index is 1
# ﻿Yassine Hamdouch
# Colliers
# General Manager
# Head of Hotels& Hospitality
# INTERNATIONAL
# 63 Bd Moulay Youssef
# 20100 Casablanca
# Morocco
# +212 (0) 5 20 30 36 31
# MAIN
# MOBILE +212 (0) 6 65 64 65 78
# +212 (0) 5 20 30 29 93
# FAX
# Yassine.Hamdouch@Colliers.com
# EMAIL
# www.colliers.com
# .
#
# ﻿Yassine Hamdouch
# Colliers
# General Manager
# Head of Hotels& Hospitality
# INTERNATIONAL
# 63 Bd Moulay Youssef
# 20100 Casablanca
# Morocco
# +212 (0) 5 20 30 36 31
# MAIN
# MOBILE +212 (0) 6 65 64 65 78
# +212 (0) 5 20 30 29 93
# FAX
# Yassine.Hamdouch@Colliers.com
# EMAIL
# www.colliers.com
# .
#
# index is 2
# ﻿ACN
# Carla Lowery
# Customer Representative
# Independent Representative
# L.F Services
# Address
# Brooklyn, NY
# USA
# 718-501-2081
# 347-706-3383
# E-Mail clowery41@verizon.net
# Website carladigital.acnret.com
# .
#
# ﻿ACN
# Carla Lowery
# Customer Representative
# Independent Representative
# L.F Services
# Address
# Brooklyn, NY
# USA
# 718-501-2081
# 347-706-3383
# E-Mail clowery41@verizon.net
# Website carladigital.acnret.com
# .
#
# index is 3
# HITACHI
# Inspire the Next
# Shoji Muramatsu, Ph. D.
# Senior Researcher
# Intelligent Sensing Systems Unit Leader
# The Second Department of Systems Research
# Hitachi, Ltd.
# Hitachi Research Laboratory
# 1-1,0mika-cho 7-chome, Hitachi-shi
# Ibaraki-ken,319-1292 Japan
# TEL:81 294 52 5111ex5367
# FAX:81 294 52 7608
# E-mail:shoji.muramatsu.xy@hitachi.com
# www.hitachi.co.jp/rd/hrl/
# .
#
# HITACHI
# Inspire the Next
# Shoji Muramatsu, Ph. D.
# Senior Researcher
# Intelligent Sensing Systems Unit Leader
# The Second Department of Systems Research
# Hitachi, Ltd.
# Hitachi Research Laboratory
# 1-1,0mika-cho 7-chome, Hitachi-shi
# Ibaraki-ken,319-1292 Japan
# TEL:81 294 52 5111ex5367
# FAX:81 294 52 7608
# E-mail:shoji.muramatsu.xy@hitachi.com
# www.hitachi.co.jp/rd/hrl/
# .
#
# index is 4
# CHIPOTLE
# MEXICAN GRILL
# CHRIS SALCEDO
# APPRENTICE
# CHIPOTLE MEXICAN GRILL, IN
# DIRECT 650.462.9154
# 650.462.1252
# 2675 EL CAMINO REAL
# FAX
# PALO ALTO, CA 94306
# .
#
# CHIPOTLE
# MEXICAN GRILL
# CHRIS SALCEDO
# APPRENTICE
# CHIPOTLE MEXICAN GRILL, IN
# DIRECT 650.462.9154
# 650.462.1252
# 2675 EL CAMINO REAL
# FAX
# PALO ALTO, CA 94306
# .
#
# index is 5
# Cambridge Logic Ltd
# lan Goldsmith
# Hardware Engineer
# Address: Queen's Road 125, CB3 4AU,
# Cambridge, UK
# Phone: +44 5858 269466
# E-Mail:ian@cambridgelogic.co.uk
# .
#
# Cambridge Logic Ltd
# lan Goldsmith
# Hardware Engineer
# Address: Queen's Road 125, CB3 4AU,
# Cambridge, UK
# Phone: +44 5858 269466
# E-Mail:ian@cambridgelogic.co.uk
# .
#
# index is 6
# Frédéric Bailly
# GROUPE SOS
# Board member
# CEO Real Estate | International action
# France +33 6 8716 28 57
# Morocco +212620 273861
# frederic.bailly@groupe-sos.org
# FAR 15, rue de la Fontaine au Roi - 75011 Paris
# Espace Bidaya -33 bis, rue le Titien
# Val Fleury -20000 Casablanca
# groupe-sos.org
# .
#
# Frederic Bailly
# GROUPE SOS
# Board member
# CEO Real Estate | International action
# France +33 6 8716 28 57
# Morocco +212620 273861
# frederic.bailly@groupe-sos.org
# FAR 15, rue de la Fontaine au Roi - 75011 Paris
# Espace Bidaya -33 bis, rue le Titien
# Val Fleury -20000 Casablanca
# groupe-sos.org
# .
#
# index is 7
# Alexis Beckman
# yogurt-in-chief
# t 650.324.0440
# f 650.324.0448
# info@culturefrozenyogurt.com
# www.culturefrozenyogurt.com
# 340 S. California Avenue
# Palo Alto
# California 94306
# 100% recycled post consumer fiber
# .
#
# Alexis Beckman
# yogurt-in-chief
# t 650.324.0440
# f 650.324.0448
# info@culturefrozenyogurt.com
# www.culturefrozenyogurt.com
# 340 S. California Avenue
# Palo Alto
# California 94306
# 100% recycled post consumer fiber
# .
#
# index is 8
# 波浪
# 割烹
# NAMI NAMI
# Kappo Dining
# Shoichi Shiono
# executive chef
# 240 Castro St.
# Mountain View, CA 94041
# Tel.650-964-6990
# .
#
# 波浪
# 割烹
# NAMI NAMI
# Kappo Dining
# Shoichi Shiono
# executive chef
# 240 Castro St.
# Mountain View, CA 94041
# Tel.650-964-6990
# .
#
# index is 9
# Marriott
# INTERNATIONAL
# Karim Cheltout
# Regional Vice President
# Lodging Development Africa
# Marriott International, Inc.
# Central Park Towers, level 12
# Dubai International Financial Centre
# PO Box 213111, Dubai, United Arab Emirates
# ...

# %%
#concatenate individual files

with open('raw_train_data.txt', 'w') as outfile:
    for i in range(1,64):
        index = '00' + str(i)
        index = index[-3:]
        with open("extracted_text/train/"+index+'.txt') as infile:
            for line in infile:
                outfile.write(line)
outfile.close()

# %%
#splitting each line into individual words

f = open('raw_test_data.txt', 'r')
f2 = open('raw_test_data_split.txt', 'w')
words = f.read().split()
words
for word in words:
    f2.write(word+'\n')
f.close()
f2.close()

# %%
#txt file to DataFrame

f3 = open('raw_test_data_split.txt', 'r')
wordslist = f3.read().split()
Os = []
for i in range(len(wordslist)):
    Os.append('O')
df = pd.DataFrame({'Word':wordslist, 'Tag':Os})

# %%
#saving to csv
df.to_csv('test_dataset_BIO.csv', index=False)
